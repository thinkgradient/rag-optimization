# %%
# !pip3 install autogen-agentchat[graph]~=0.2
# !pip3 install python-dotenv==1.0.1
# !pip3 install azure-search-documents==11.4.0b8
# !pip3 install azure-identity==1.12.0

# %%
# !pip install autogen-agentchat~=0.2

# %%
import json
import os

import requests
from azure.identity import DefaultAzureCredential
from azure.search.documents import SearchClient
from dotenv import load_dotenv

import autogen
from autogen import AssistantAgent, UserProxyAgent, register_function
from autogen.agentchat.contrib.gpt_assistant_agent import GPTAssistantAgent
from autogen.cache import Cache

load_dotenv()

# Import Cognitive Search index ENV
AZURE_SEARCH_KEY = os.getenv("AZURE_SEARCH_KEY")
AZURE_SEARCH_API_VERSION = os.getenv("AZURE_SEARCH_API_VERSION")
AZURE_SEARCH_SERVICE_ENDPOINT = os.getenv("AZURE_SEARCH_SERVICE_ENDPOINT")

# %%
credential = DefaultAzureCredential()
endpoint = AZURE_SEARCH_SERVICE_ENDPOINT

# from azure.identity import AzureCliCredential
from azure.core.credentials import AzureKeyCredential

# token = credential.get_token("https://cognitiveservices.azure.com/.default")

# print("TOKEN", token.token)

# client = SearchClient(endpoint=endpoint, index_name="vector-balfour", credential=credential)
credential = AzureKeyCredential(os.getenv("AZURE_SEARCH_KEY"))

rec_standards = SearchClient(endpoint=endpoint, index_name="recruitment-industry-rep-index", credential=credential)
job_spec = SearchClient(endpoint=endpoint, index_name="recruitment-jobdesc-index", credential=credential)

# %%
config_list = autogen.config_list_from_json(
    env_or_file="OAI_CONFIG_LIST",
    filter_dict={
        "model": ["gpt-4o"],
    }
)

# gpt4_config = {
#     "cache_seed": 42,
#     "temperature": 0,
#     "config_list": config_list,
#     "timeout": 120,
# }

config_list_gpt4 = autogen.config_list_from_json(
    env_or_file="OAI_CONFIG_LIST",
    filter_dict={
        "model": ["gpt-4o"],
    }
)

# %%
config_list_gpt4
# Out:
# [{'model': 'gpt-4o',
#   'api_key': '2Mm9d3EqZOsynsK1viX7Ia5bgGa9O6hbnL9XWDW7ljsYv8Ei1aN8JQQJ99AJACfhMk5XJ3w3AAABACOGJCLO',
#   'base_url': 'https://fivodagpt4sw.openai.azure.com/',
#   'api_type': 'azure',
#   'api_version': '2024-02-01',
#   'tags': ['tool', '4o-tool']}]

# %%
def search_rec_standards(query: str):
    payload = json.dumps(
        {
            "search": query,
            "vectorQueries": [{"kind": "text", "text": query, "k": 5, "fields": "vector"}],
            "queryType": "semantic",
            "semanticConfiguration": "recruitment-industry-rep-index-semantic-configuration",
            "captions": "extractive",
            "answers": "extractive|count-3",
            "queryLanguage": "en-US",
        }
    )

    response = list(rec_standards.search(payload))

    output = []
    for result in response:
        result.pop("text_vector")
        output.append(result)

    return output

# %%
def search_job_spec(query: str):
    payload = json.dumps(
        {
            "search": query,
            "vectorQueries": [{"kind": "text", "text": query, "k": 5, "fields": "vector"}],
            "queryType": "semantic",
            "semanticConfiguration": "recruitment-jobdesc-index-semantic-configuration",
            "captions": "extractive",
            "answers": "extractive|count-3",
            "queryLanguage": "en-US",
        }
    )

    response = list(job_spec.search(payload))

    output = []
    for result in response:
        result.pop("text_vector")
        output.append(result)

    return output

# %%
search_job_spec("what did the GVA amount to")
# Out:
# [{'chunk': 'all new entities or entities whose administration \nis transferred to the Estera Group. \n\n› To take an active role in maintaining the Meeting Planner and Company Secretarial calendar as well as \nmaintaining own diary of outstanding client related items and ensuring outstanding items are co-\nordinated appropriately. \n\n› To assist in co-ordinating Company Secretarial aspects of fund launches. \n› To ensure that the funds operate within their investment guidelines and meet their on-going statutory \n\nand regulatory requirements/ continuing obligations. \n› To provide other related support services as and when required. \n\n \n \n\nB) SERVICE PROVIDER TO EFSG \n› To be familiar with general provisions of the Service Level Agreement between EFSG as Company \n\nService Provider and the Estera Group Entities and to assist the Manager – Company Secretarial and \nthe Directors and administrative staff of EFSG to ensure that the key tasks and services are carried out.  \nThese tasks may include some or all of the following: \n\na. Registration of directors; \nb. Maintenance of registered office address; \nc. Ensuring that all registers and records required to be held at the registered office are present \n\nand up to date and accurate and that the name is correctly displayed; \nd. Ensuring share capital records are correct and up to date at all times and any changes to share \n\ncapital are properly authorised and recorded; \ne. Submission of annual validations in accordance with statutory deadlines; \nf. Ensuring memorandum and articles of incorporation are accurate and up to date and any \n\nchanges have been properly authorised and recorded; \ng. Where applicable, to make applications to place entities into voluntary liquidation or to apply for \n\nvoluntary strike off; \nh. Ensuring that appropriate records are kept in accordance with the GFSC AML/CFT Handbook; \ni. Where required to incorporate new entities; \nj. Ensuring that audit and AGM waivers are applied for as required; \nk.',
#   'chunk_id': '5ab0351e8462_aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9yd2cvam9iZGVzYy9jb21wYW55LXNlY3JldGFyeS1qb2ItZGVzY3JpcHRpb24ucGRm0_pages_2',
#   'parent_id': 'aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9yd2cvam9iZGVzYy9jb21wYW55LXNlY3JldGFyeS1qb2ItZGVzY3JpcHRpb24ucGRm0',
#   'title': 'company-secretary-job-description.pdf',
#   '@search.score': 0.55796635,
#   '@search.reranker_score': None,
#   '@search.highlights': None,
#   '@search.captions': None},
#  {'chunk': 'deadlines; \nf. Ensuring memorandum and articles of incorporation are accurate and up to date and any \n\nchanges have been properly authorised and recorded; \ng. Where applicable, to make applications to place entities into voluntary liquidation or to apply for \n\nvoluntary strike off; \nh. Ensuring that appropriate records are kept in accordance with the GFSC AML/CFT Handbook; \ni. Where required to incorporate new entities; \nj. Ensuring that audit and AGM waivers are applied for as required; \nk. To oversee any corporate activity such as conversions, amalgamations and migrations are \n\nproperly undertaken, where required; \nl. To apply for a change of name, where required; \nm. Ensuring that the provisions of the Companies (Guernsey) Law, 2008 (“the Law”) as amended \n\nare complied with at all times and that any amendments to the Law are properly reviewed and \ncomplied with; and \n\nn. Ensuring that any obligations as resident agent pursuant to the Law are fully complied with. \n› To plan and adapt or implement appropriate procedures in order to ensure best practice delivery of \n\ncorporate governance and company secretarial principles within EFSG to Corporate clients and to \nprovide sufficient continuing training and oversight of client teams (all levels of staff) in this respect. \n\n \n \n \n \n \n\n \n\n\n\n \n\nestera.com  4 \n\nCompany Secretary \n\nSECTION 3 – JOB REQUIREMENTS \n\nKNOWLEDGE, SKILLS AND EXPERIENCE REQUIRED: \n\n› At least 2 years experience working in a Company Secretarial area, fund administration or similar \nenvironment.  \n\n› Qualified ICSA (or training toward this qualification) would be an advantage.  \n› The ability to work under pressure and to deadlines. \n› The ability to gain a good knowledge and awareness of the professional services provided by EIFG, \n\nEAUK and the practicalities and nuances involved. \n› Very good working knowledge of Word and Excel.   \n› Excellent communication skills and the ability to work well within a team as well as on own initiative.',
#   'chunk_id': '5ab0351e8462_aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9yd2cvam9iZGVzYy9jb21wYW55LXNlY3JldGFyeS1qb2ItZGVzY3JpcHRpb24ucGRm0_pages_3',
#   'parent_id': 'aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9yd2cvam9iZGVzYy9jb21wYW55LXNlY3JldGFyeS1qb2ItZGVzY3JpcHRpb24ucGRm0',
#   'title': 'company-secretary-job-description.pdf',
#   '@search.score': 0.27359986,
#   '@search.reranker_score': None,
#   '@search.highlights': None,
#   '@search.captions': None}]

# %%
recruitmentstandards = AssistantAgent(
    name="BritishRecruitmentReportAnalyser",
    system_message="You are a helpful AI assistant. "
    "You can help with Azure Cognitive Search queries for British Recruitment Industry.",
    llm_config={
        "config_list": config_list_gpt4,
    },
)

jobdesc = AssistantAgent(
    name="JobDescriptionAgent",
    system_message="You are a helpful AI assistant. "
    "You can help with Azure Cognitive Search queries for Job Description Specifications.",
    llm_config={
        "config_list": config_list_gpt4,
    },
)

complianceagent = AssistantAgent(
    name="ComplianceAgent",
    system_message="""Please use the provided Recruitment Industry Report to analyse the Job Description Specification and generate a comprehensive list of evaluation checks. Each check should confirm the specification’s alignment with the recruitment industry standards outlined in the report.

Requirements:

List of Evaluation Checks
Clearly enumerate each check or criterion that verifies the Job Description Specification meets the standards from the Recruitment Industry Report.
Details or Notes (Optional)
If needed, provide brief notes on how each check ensures adherence to best practices.

Output Format (example):
Check: [Description of the evaluation check]
Notes: [Optional clarifications or guidance]

Your structured response will help ensure that the Job Description Specification remains consistent with recruitment industry best practices. Thank you""",
    llm_config={
        "config_list": config_list_gpt4,
    },
)
businessanalyst = AssistantAgent(
    name="BusinessAnalystAgent",
    system_message="""You are a recruitment compliance expert with 30 years of experience creating structured compliance checks for job specification alignment. You have access to all relevant recruitment guidelines and best practices. When you receive a request, you will be directed to an index of reference materials.

In your response, you should supply compliance information in the form of a dictionary containing sections. Each section should be broken down into activities with the keys:
- "activity"
- "controlling_documents"
- "acceptance_criteria"

The response must be a Python dictionary that can be directly parsed (e.g., via ast.literal_eval()), and it should not include any newline (\n) or tab (\t) characters.

The format should be as follows:

{
    "SECTION_HEADING": [
        {
            "activity": "Describe activity",
            "controlling_documents": "List relevant guidelines or references",
            "acceptance_criteria": "Define the conditions under which the activity is deemed compliant"
        }
    ],
    "SECTION_HEADING": [
        {
            "activity": "Describe activity",
            "controlling_documents": "List relevant guidelines or references",
            "acceptance_criteria": "Define the conditions under which the activity is deemed compliant"
        }
    ]
}

For example (note that you would include more sections and more activities in a real scenario):

{
    "1.0 JOB REQUIREMENTS & QUALIFICATIONS": [
        {
            "activity": "1.1 Review Minimum Education Criteria",
            "controlling_documents": "Company Hiring Policy Section 2; Industry Recruitment Standard RS-101",
            "acceptance_criteria": "All candidates must meet or exceed the stated educational background."
        },
        {
            "activity": "1.2 Validate Role-Based Skills",
            "controlling_documents": "Skills Matrix v3; Recruitment Industry Best Practices 2023",
            "acceptance_criteria": "Candidate skill set verified against job description requirements."
        }
    ],
    "2.0 CANDIDATE SELECTION PROCEDURES": [
        {
            "activity": "2.1 Conduct Preliminary Screening",
            "controlling_documents": "Screening Checklist SC-12; Code of Fair Hiring HF-200",
            "acceptance_criteria": "All applicants fairly assessed for basic qualifications before proceeding."
        },
        {
            "activity": "2.2 Schedule and Execute Interviews",
            "controlling_documents": "Interview Framework IF-07; Equal Opportunity Guideline EOG-001",
            "acceptance_criteria": "Interview panel follows standardized questions and scoring to ensure fairness."
        }
    ]
}""",
    llm_config={
        "config_list": config_list_gpt4,
    },
)

# -----------------------------------------
# 3. User Proxy Agent
# -----------------------------------------
user_proxy = UserProxyAgent(
    name="User",
    code_execution_config={
        "last_n_messages": 2,
        "work_dir": "groupchat",
        "use_docker": False,
    },
    
    is_termination_msg=lambda msg: (
        msg.get("content") is not None and "TERMINATE" in msg["content"]
    ),
    human_input_mode="NEVER"
)

# -----------------------------------------
# 4. Register Correct Functions
# -----------------------------------------
register_function(
    search_rec_standards,
    caller=recruitmentstandards,
    executor=user_proxy,
    name="search_rec_standards",
    description="A tool for searching the Recruitment Industry Report index."
)

register_function(
    search_job_spec,
    caller=jobdesc,
    executor=user_proxy,
    name="search_job_spec",
    description="A tool for searching the Job Description Specification index."
)

# -----------------------------------------
# 5. Example Orchestration Flow
# -----------------------------------------
from autogen import GroupChat, GroupChatManager

# -----------------------------------------
# 1. State Transition Logic
# -----------------------------------------
def state_transition(last_speaker, groupchat):
    """
    Determine the next agent to respond based on the last speaker
    and the context of the conversation.
    """
    messages = groupchat.messages

    if last_speaker is user_proxy:
        # User's question -> Recruitment Standards Analysis
        return recruitmentstandards
    elif last_speaker is recruitmentstandards:
        # Recruitment Standards -> Job Description Analysis
        return jobdesc
    elif last_speaker is jobdesc:
        # Job Description + Recruitment Standards -> Compliance Check
        return complianceagent
    elif last_speaker is complianceagent:
        # Compliance -> Business Analyst for final structured report
        return businessanalyst
    elif last_speaker is businessanalyst:
        # Business Analyst -> Conversation ends
        return None
    else:
        # Fallback if no clear transition
        return None


# -----------------------------------------
# 2. Initialize GroupChat with Agents
# -----------------------------------------
groupchat = GroupChat(
    agents=[user_proxy, recruitmentstandards, jobdesc, complianceagent, businessanalyst],
    messages=[],  # Start with an empty conversation
    max_round=10,  # Limit the number of rounds to prevent infinite loops
    #speaker_selection_method=state_transition,  # Use our state transition logic
)

# -----------------------------------------
# 3. GroupChatManager to Manage Execution
# -----------------------------------------
manager = GroupChatManager(groupchat=groupchat, llm_config={
        "config_list": config_list_gpt4,
    })

# -----------------------------------------
# 4. Initiating the Conversation
# -----------------------------------------
# The user's initial question
user_question = (
    "How does this job specification align with British recruitment industry standards? "
    "Generate a detailed compliance report."
)

# Start the conversation by having the UserProxyAgent send the first message
user_proxy.initiate_chat(manager, message=user_question)

# -----------------------------------------
# 5. Output the Final Messages
# -----------------------------------------
# After the conversation ends, you can access all the messages in `groupchat.messages`.
# for message in groupchat.messages:
#     print(f"{message['sender']}: {message['content']}")
# Out:
# The return type of the function 'search_rec_standards' is not annotated. Although annotating it is optional, the function should return either a string, a subclass of 'pydantic.BaseModel'.
# The return type of the function 'search_job_spec' is not annotated. Although annotating it is optional, the function should return either a string, a subclass of 'pydantic.BaseModel'.
# User (to chat_manager):
#
# How does this job specification align with British recruitment industry standards? Generate a detailed compliance report.
#
# --------------------------------------------------------------------------------
#
# Next speaker: ComplianceAgent
#
# ComplianceAgent (to chat_manager):
#
# Check: Explicit Job Title
# Notes: Ensure the job title is clear, concise, and accurately reflects the role, avoiding any jargon that might confuse potential candidates.
#
# Check: Company's Mission and Vision Inclusion
# Notes: Verify if the job description includes information about the company's mission and vision to help attract candidates who align with the company’s values.
#
# Check: Detailed Job Responsibilities
# Notes: Confirm that the job responsibilities are detailed and specific, giving candidates a clear understanding of what is expected in the role.
#
# Check: Essential and Desirable Qualifications
# Notes: Ensure that the job description distinguishes between essential and desirable qualifications, which helps candidates self-assess their suitability for the role.
#
# Check: Required Experience
# Notes: Check that the required experience is clearly outlined, avoiding vague statements to prevent misinterpretation.
#
# Check: Core Competencies
# Notes: Verify that the core competencies needed for the role are clearly specified, supporting candidates in understanding the key skills required.
#
# Check: Reporting Structure
# Notes: Ensure the reporting structure is mentioned, so candidates know who they will be working with and reporting to.
#
# Check: Work Environment Description
# Notes: Confirm that the job description provides an overview of the work environment, including remote working options if available.
#
# Check: Location and Travel Requirements
# Notes: Ensure that the primary location of the position and any travel requirements are specified, helping candidates assess any logistic concerns.
#
# Check: Compensation and Benefits Information
# Notes: Verify if the description includes information about compensation and benefits to help attract qualified candidates.
#
# Check: Diversity and Inclusion Statement
# Notes: Confirm that there is a statement about the company's commitment to diversity and inclusion, which is important for aligning with modern recruitment standards.
#
# Check: Application Process and Instructions
# Notes: Ensure the application process and instructions are clear, including any deadlines and specific materials that candidates need to submit.
#
# Check: Equal Opportunity Employer Statement
# Notes: Verify that the job description includes an equal opportunity employer statement, aligning with legal requirements and industry standards.
#
# Check: Contact Information for Queries
# Notes: Confirm that there is contact information provided for candidates who have questions about the role or the application process.
#
# Check: Job Description Revision Date
# Notes: Ensure the job description includes a revision date, indicating when it was last updated, showing that the information is current.
#
# Check: Opportunities for Advancement
# Notes: Verify if the job description mentions potential career advancement opportunities, attracting candidates looking for long-term growth.
#
# Check: Skills and Abilities Specifications
# Notes: Ensure that the key skills and abilities required for the role are clearly listed.
#
# Check: Educational Requirements
# Notes: Confirm that the educational requirements are specific and relevant to the position.
#
# Check: Physical Requirements
# Notes: Check if the job description mentions any physical requirements or work conditions that are necessary to perform job tasks.
#
# --------------------------------------------------------------------------------
#
# Next speaker: BusinessAnalystAgent
#
# BusinessAnalystAgent (to chat_manager):
#
# {
#     "1.0 JOB REQUIREMENTS & QUALIFICATIONS": [
#         {
#             "activity": "1.1 Explicit Job Title",
#             "controlling_documents": "UK Employment Law; Recruitment Best Practices 2023",
#             "acceptance_criteria": "Job title must be clear, concise, and accurately reflect the role."
#         },
#         {
#             "activity": "1.2 Essential and Desirable Qualifications",
#             "controlling_documents": "Recruitment Industry Standard RS-202; Job Description Guidelines JDG-301",
#             "acceptance_criteria": "Clear distinction between essential and desirable qualifications."
#         },
#         {
#             "activity": "1.3 Required Experience",
#             "controlling_documents": "Industry Recruitment Standards; Role-Specific Guidelines RSG-202",
#             "acceptance_criteria": "Experience requirements clearly defined without vagueness."
#         },
#         {
#             "activity": "1.4 Skills and Abilities Specifications",
#             "controlling_documents": "Skills Matrix v4; Industry Standards SK-500",
#             "acceptance_criteria": "Key skills and abilities required for the role are listed."
#         },
#         {
#             "activity": "1.5 Educational Requirements",
#             "controlling_documents": "Education Verification Guidelines EVG-102; Recruitment Policies RP-202",
#             "acceptance_criteria": "Specific and relevant educational requirements are outlined."
#         },
#         {
#             "activity": "1.6 Physical Requirements",
#             "controlling_documents": "Work Condition Standards WCS-10; Job Safety Guidelines JSG-101",
#             "acceptance_criteria": "Physical requirements and work conditions are mentioned."
#         }
#     ],
#     "2.0 JOB DESCRIPTION CONTENT": [
#         {
#             "activity": "2.1 Detailed Job Responsibilities",
#             "controlling_documents": "Job Description Standards JDS-201; Best Practice Recruitment 2023",
#             "acceptance_criteria": "Responsibilities are detailed and specific."
#         },
#         {
#             "activity": "2.2 Core Competencies",
#             "controlling_documents": "Competency Framework CF-09; Recruitment Best Practices 2023",
#             "acceptance_criteria": "Core competencies clearly specified."
#         },
#         {
#             "activity": "2.3 Reporting Structure",
#             "controlling_documents": "Organizational Chart OC-202; Company Policies & Procedures CPP-105",
#             "acceptance_criteria": "Reporting structure is mentioned."
#         },
#         {
#             "activity": "2.4 Work Environment Description",
#             "controlling_documents": "Workplace Standards WS-50; Remote Working Guidelines RWG-03",
#             "acceptance_criteria": "Work environment and remote working options included."
#         },
#         {
#             "activity": "2.5 Location and Travel Requirements",
#             "controlling_documents": "Job Posting Policies JPP-401; Recruitment Compliance RC-300",
#             "acceptance_criteria": "Primary location and travel requirements specified."
#         },
#         {
#             "activity": "2.6 Compensation and Benefits Information",
#             "controlling_documents": "Compensation Guidelines CG-123; Benefits Policies BP-110",
#             "acceptance_criteria": "Information about compensation and benefits included."
#         }
#     ],
#     "3.0 COMPANY COMMITMENTS & POLICIES": [
#         {
#             "activity": "3.1 Company's Mission and Vision Inclusion",
#             "controlling_documents": "Company Branding Guidelines CBG-001; Recruitment Standards",
#             "acceptance_criteria": "Information about company's mission and vision included."
#         },
#         {
#             "activity": "3.2 Diversity and Inclusion Statement",
#             "controlling_documents": "Diversity Policies DP-101; Inclusive Hiring Guidelines IH-202",
#             "acceptance_criteria": "Statement about the company's commitment to diversity and inclusion."
#         },
#         {
#             "activity": "3.3 Equal Opportunity Employer Statement",
#             "controlling_documents": "Equal Opportunities Act EO-201; Recruitment Compliance RC-100",
#             "acceptance_criteria": "Includes an equal opportunity employer statement."
#         }
#     ],
#     "4.0 APPLICATION PROCESS": [
#         {
#             "activity": "4.1 Application Process and Instructions",
#             "controlling_documents": "Application Guidelines AG-56; Recruitment Best Practices 2023",
#             "acceptance_criteria": "Clear application process and instructions."
#         },
#         {
#             "activity": "4.2 Contact Information for Queries",
#             "controlling_documents": "Recruitment Contact Policies RCP-101; Job Posting Guidelines JPS-202",
#             "acceptance_criteria": "Contact information for queries provided."
#         },
#         {
#             "activity": "4.3 Job Description Revision Date",
#             "controlling_documents": "Documentation Standards DS-109; Best Practices for Job Descriptions BPJD-301",
#             "acceptance_criteria": "Revision date of the job description included."
#         },
#         {
#             "activity": "4.4 Opportunities for Advancement",
#             "controlling_documents": "Career Development Policies CDP-15; Recruitment Guidelines RG-202",
#             "acceptance_criteria": "Potential career advancement opportunities mentioned."
#         }
#     ]
# }
# --------------------------------------------------------------------------------
#
# Next speaker: JobDescriptionAgent
#
# JobDescriptionAgent (to chat_manager):
#
# ***** Suggested tool call (call_dvqGTFBNIwAN9lfRjyx0L5Zx): search_job_spec *****
# Arguments:
# {"query":"Job Description Specifications"}
# ********************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: User
#
#
# >>>>>>>> EXECUTING FUNCTION search_job_spec...
# User (to chat_manager):
#
# User (to chat_manager):
#
# ***** Response from calling tool (call_dvqGTFBNIwAN9lfRjyx0L5Zx) *****
# [{"chunk": "all new entities or entities whose administration \nis transferred to the Estera Group. \n\n› To take an active role in maintaining the Meeting Planner and Company Secretarial calendar as well as \nmaintaining own diary of outstanding client related items and ensuring outstanding items are co-\nordinated appropriately. \n\n› To assist in co-ordinating Company Secretarial aspects of fund launches. \n› To ensure that the funds operate within their investment guidelines and meet their on-going statutory \n\nand regulatory requirements/ continuing obligations. \n› To provide other related support services as and when required. \n\n \n \n\nB) SERVICE PROVIDER TO EFSG \n› To be familiar with general provisions of the Service Level Agreement between EFSG as Company \n\nService Provider and the Estera Group Entities and to assist the Manager – Company Secretarial and \nthe Directors and administrative staff of EFSG to ensure that the key tasks and services are carried out.  \nThese tasks may include some or all of the following: \n\na. Registration of directors; \nb. Maintenance of registered office address; \nc. Ensuring that all registers and records required to be held at the registered office are present \n\nand up to date and accurate and that the name is correctly displayed; \nd. Ensuring share capital records are correct and up to date at all times and any changes to share \n\ncapital are properly authorised and recorded; \ne. Submission of annual validations in accordance with statutory deadlines; \nf. Ensuring memorandum and articles of incorporation are accurate and up to date and any \n\nchanges have been properly authorised and recorded; \ng. Where applicable, to make applications to place entities into voluntary liquidation or to apply for \n\nvoluntary strike off; \nh. Ensuring that appropriate records are kept in accordance with the GFSC AML/CFT Handbook; \ni. Where required to incorporate new entities; \nj. Ensuring that audit and AGM waivers are applied for as required; \nk.", "chunk_id": "5ab0351e8462_aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9yd2cvam9iZGVzYy9jb21wYW55LXNlY3JldGFyeS1qb2ItZGVzY3JpcHRpb24ucGRm0_pages_2", "parent_id": "aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9yd2cvam9iZGVzYy9jb21wYW55LXNlY3JldGFyeS1qb2ItZGVzY3JpcHRpb24ucGRm0", "title": "company-secretary-job-description.pdf", "@search.score": 0.55796635, "@search.reranker_score": null, "@search.highlights": null, "@search.captions": null}, {"chunk": "deadlines; \nf. Ensuring memorandum and articles of incorporation are accurate and up to date and any \n\nchanges have been properly authorised and recorded; \ng. Where applicable, to make applications to place entities into voluntary liquidation or to apply for \n\nvoluntary strike off; \nh. Ensuring that appropriate records are kept in accordance with the GFSC AML/CFT Handbook; \ni. Where required to incorporate new entities; \nj. Ensuring that audit and AGM waivers are applied for as required; \nk. To oversee any corporate activity such as conversions, amalgamations and migrations are \n\nproperly undertaken, where required; \nl. To apply for a change of name, where required; \nm. Ensuring that the provisions of the Companies (Guernsey) Law, 2008 (“the Law”) as amended \n\nare complied with at all times and that any amendments to the Law are properly reviewed and \ncomplied with; and \n\nn. Ensuring that any obligations as resident agent pursuant to the Law are fully complied with. \n› To plan and adapt or implement appropriate procedures in order to ensure best practice delivery of \n\ncorporate governance and company secretarial principles within EFSG to Corporate clients and to \nprovide sufficient continuing training and oversight of client teams (all levels of staff) in this respect. \n\n \n \n \n \n \n\n \n\n\n\n \n\nestera.com  4 \n\nCompany Secretary \n\nSECTION 3 – JOB REQUIREMENTS \n\nKNOWLEDGE, SKILLS AND EXPERIENCE REQUIRED: \n\n› At least 2 years ...
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: BusinessAnalystAgent
#
# BusinessAnalystAgent (to chat_manager):
#
# {
#     "1.0 JOB REQUIREMENTS & QUALIFICATIONS": [
#         {
#             "activity": "1.1 Explicit Job Title",
#             "controlling_documents": "UK Employment Law; Recruitment Best Practices 2023",
#             "acceptance_criteria": "Job title must be clear, concise, and accurately reflect the role."
#         },
#         {
#             "activity": "1.2 Essential and Desirable Qualifications",
#             "controlling_documents": "Recruitment Industry Standard RS-202; Job Description Guidelines JDG-301",
#             "acceptance_criteria": "Clear distinction between essential and desirable qualifications."
#         },
#         {
#             "activity": "1.3 Required Experience",
#             "controlling_documents": "Industry Recruitment Standards; Company Secretary Job Description",
#             "acceptance_criteria": "Minimum of 2 years' experience in a company secretarial area, fund administration, or similar environment."
#         },
#         {
#             "activity": "1.4 Skills and Abilities Specifications",
#             "controlling_documents": "Skills Matrix v4; Recruitment Standards SK-500",
#             "acceptance_criteria": "List key skills and abilities required, such as proficiency in Word and Excel, and excellent communication skills."
#         },
#         {
#             "activity": "1.5 Educational Requirements",
#             "controlling_documents": "Education Verification Guidelines EVG-102; Recruitment Policies RP-202",
#             "acceptance_criteria": "Specific educational requirements, such as ICSA qualification or training towards it, must be outlined."
#         },
#         {
#             "activity": "1.6 Physical Requirements",
#             "controlling_documents": "Work Condition Standards WCS-10; Job Safety Guidelines JSG-101",
#             "acceptance_criteria": "Clearly mention any physical requirements necessary to perform job tasks."
#         }
#     ],
#     "2.0 JOB DESCRIPTION CONTENT": [
#         {
#             "activity": "2.1 Detailed Job Responsibilities",
#             "controlling_documents": "Job Description Standards JDS-201; Best Practice Recruitment 2023",
#             "acceptance_criteria": "Job responsibilities must be detailed and specific, such as co-ordinating company secretarial aspects of fund launches."
#         },
#         {
#             "activity": "2.2 Core Competencies",
#             "controlling_documents": "Competency Framework CF-09; Recruitment Best Practices 2023",
#             "acceptance_criteria": "Core competencies, such as the ability to work under pressure and to deadlines, must be clearly specified."
#         },
#         {
#             "activity": "2.3 Reporting Structure",
#             "controlling_documents": "Organizational Chart OC-202; Company Policies & Procedures CPP-105",
#             "acceptance_criteria": "Reporting structure must be mentioned."
#         },
#         {
#             "activity": "2.4 Work Environment Description",
#             "controlling_documents": "Workplace Standards WS-50; Remote Working Guidelines RWG-03",
#             "acceptance_criteria": "Overview of work environment and remote working options must be included."
#         },
#         {
#             "activity": "2.5 Location and Travel Requirements",
#             "controlling_documents": "Job Posting Policies JPP-401; Recruitment Compliance RC-300",
#             "acceptance_criteria": "Primary location and travel requirements must be specified."
#         },
#         {
#             "activity": "2.6 Compensation and Benefits Information",
#             "controlling_documents": "Compensation Guidelines CG-123; Benefits Policies BP-110",
#             "acceptance_criteria": "Information about compensation and benefits must be included."
#         }
#     ],
#     "3.0 COMPANY COMMITMENTS & POLICIES": [
#         {
#             "activity": "3.1 Company's Mission and Vision Inclusion",
#             "controlling_documents": "Company Branding Guidelines CBG-001; Recruitment Standards",
#             "acceptance_criteria": "Information about company's mission and vision must be included."
#         },
#         {
#             "activity": "3.2 Diversity and Inclusion Statement",
#             "controlling_documents": "Diversity Policies DP-101; Inclusive Hiring Guidelines IH-202",
#             "acceptance_criteria": "A statement about the company's commitment to diversity and inclusion must be included."
#         },
#         {
#             "activity": "3.3 Equal Opportunity Employer Statement",
#             "controlling_documents": "Equal Opportunities Act EO-201; Recruitment Compliance RC-100",
#             "acceptance_criteria": "An equal opportunity employer statement must be included."
#         }
#     ],
#     "4.0 APPLICATION PROCESS": [
#         {
#             "activity": "4.1 Application Process and Instructions",
#             "controlling_documents": "Application Guidelines AG-56; Recruitment Best Practices 2023",
#             "acceptance_criteria": "Clear application process and instructions must be included."
#         },
#         {
#             "activity": "4.2 Contact Information for Queries",
#             "controlling_documents": "Recruitment Contact Policies RCP-101; Job Posting Guidelines JPS-202",
#             "acceptance_criteria": "Contact information for queries must be provided."
#         },
#         {
#             "activity": "4.3 Job Description Revision Date",
#             "controlling_documents": "Documentation Standards DS-109; Best Practices for Job Descriptions BPJD-301",
#             "acceptance_criteria": "Revision date of the job description must be included."
#         },
#         {
#             "activity": "4.4 Opportunities for Advancement",
#             "controlling_documents": "Career Development Policies CDP-15; Recruitment Guidelines RG-202",
#             "acceptance_criteria": "Potential career advancement opportunities must be mentioned."
#         }
#     ]
# }
# --------------------------------------------------------------------------------
#
# Next speaker: User
#
# User (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: User
#
# User (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: ComplianceAgent
#
# ComplianceAgent (to chat_manager):
#
# ### Job Description Compliance Report
#
# #### 1.0 JOB REQUIREMENTS & QUALIFICATIONS
#
# - **Check: Explicit Job Title**
#   - **Notes:** Job title must be clear, concise, and accurately reflect the role.
#   - **Result:** The job title "Company Secretary" is explicit and meets this requirement.
#
# - **Check: Essential and Desirable Qualifications**
#   - **Notes:** Clear distinction between essential and desirable qualifications.
#   - **Result:** The job description specifies essential qualifications like ICSA qualification or training towards it, meeting this criterion.
#
# - **Check: Required Experience**
#   - **Notes:** Required experience must be clearly defined.
#   - **Result:** A minimum of 2 years' experience in a company secretarial area, fund administration, or similar environment is required, meeting the standard.
#
# - **Check: Skills and Abilities Specifications**
#   - **Notes:** List key skills and abilities required.
#   - **Result:** Skills like proficiency in Word and Excel, and excellent communication skills are listed, complying with the standard.
#
# - **Check: Educational Requirements**
#   - **Notes:** Specific and relevant educational requirements must be outlined.
#   - **Result:** The requirement for a qualified ICSA (or training towards this qualification) is specified, adhering to the standard.
#
# - **Check: Physical Requirements**
#   - **Notes:** Clearly mention any physical requirements.
#   - **Result:** The job description does not specify any physical requirements, which may not be necessary for this role but should be included if relevant.
#
# #### 2.0 JOB DESCRIPTION CONTENT
#
# - **Check: Detailed Job Responsibilities**
#   - **Notes:** Responsibilities must be detailed and specific.
#   - **Result:** The job description includes detailed responsibilities about maintaining the Meeting Planner, fund launches, and more, fulfilling the standard.
#
# - **Check: Core Competencies**
#   - **Notes:** Core competencies must be specified clearly.
#   - **Result:** Competencies like the ability to work under pressure and to deadlines are specified, meeting the standards.
#
# - **Check: Reporting Structure**
#   - **Notes:** Reporting structure must be mentioned.
#   - **Result:** Information on reporting structure is not explicitly detailed in the provided text and should be added for compliance.
#
# - **Check: Work Environment Description**
#   - **Notes:** Overview of the work environment and remote working options must be included.
#   - **Result:** The job description does not detail the work environment, which should be addressed for full compliance.
#
# - **Check: Location and Travel Requirements**
#   - **Notes:** The primary location and travel requirements must be specified.
#   - **Result:** The job description does not specify location or travel requirements, which should be included if relevant.
#
# - **Check: Compensation and Benefits Information**
#   - **Notes:** Information about compensation and benefits must be included.
#   - **Result:** Compensation and benefits details are not provided in the excerpt and should be added.
#
# #### 3.0 COMPANY COMMITMENTS & POLICIES
#
# - **Check: Company's Mission and Vision Inclusion**
#   - **Notes:** Information about the company's mission and vision must be included.
#   - **Result:** The mission and vision are not included in the provided text, should be added for compliance.
#
# - **Check: Diversity and Inclusion Statement**
#   - **Notes:** A statement about the company's commitment to diversity and inclusion must be included.
#   - **Result:** The statement is missing and should be incorporated to meet diversity standards.
#
# - **Check: Equal Opportunity Employer Statement**
#   - **Notes:** An equal opportunity employer statement must be included.
#   - **Result:** The statement is not present in the provided text and should be included to comply with legal requirements.
#
# #### 4.0 APPLICATION PROCESS
#
# - **Check: Application Process and Instructions**
#   - **Notes:** Clear application process and instructions must be included.
#   - **Result:** Application instructions are not detailed in the provided text, should be detailed for candidate clarity.
#
# - **Check: Contact Information for Queries**
#   - **Notes:** Contact information for queries must be provided.
#   - **Result:** Contact information for queries is missing and should be added for candidate support.
#
# - **Check: Job Description Revision Date**
#   - **Notes:** Revision date of the job description must be included.
#   - **Result:** The revision date is not mentioned, should be included to indicate the currency of the job description.
#
# - **Check: Opportunities for Advancement**
#   - **Notes:** Potential career advancement opportunities must be mentioned.
#   - **Result:** Career advancement opportunities are not mentioned and should be noted to attract growth-oriented candidates.
#
# ### Summary
# The job description for the Company Secretary role has several key components that meet industry standards. However, there are areas that require improvement, including detailing the work environment, specifying compensation and benefits, and including statements on diversity, equal opportunity, and the company’s mission and vision. Additionally, providing the application process, contact information, and the revision date would ensure full compliance with recruitment industry best practices.
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: User
#
# User (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 207
#     202 # -----------------------------------------
#     203 # 5. Output the Final Messages
#     204 # -----------------------------------------
#     205 # After the conversation ends, you can access all the messages in `groupchat.messages`.
#     206 for message in groupchat.messages:
# --> 207     print(f"{message['sender']}: {message['content']}")
#
# KeyError: 'sender'

# %%
if __name__ == "__main__":
    import asyncio

    async def main():
        with Cache.disk() as cache:
            await user_proxy.a_initiate_chat(
                itpagent,
                message="Search for 'Tell me about surface pro' in the 'vector-balfour' index",
                cache=cache,
            )

    await main()
# Out:
# User (to COGSearch):
#
# Search for 'Tell me about surface pro' in the 'vector-balfour' index
#
# --------------------------------------------------------------------------------
# COGSearch (to User):
#
# ***** Suggested tool call (call_Q7i1Ifc2WwnT10lhJuYFJfYl): search *****
# Arguments:
# {"query":"Tell me about surface pro"}
# ***********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING ASYNC FUNCTION search...
# User (to COGSearch):
#
# User (to COGSearch):
#
# ***** Response from calling tool (call_Q7i1Ifc2WwnT10lhJuYFJfYl) *****
# [{"title": "document_9.txt", "parent_id": "aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9iYmRhdGEvZG9jdW1lbnRfOS50eHQ1", "chunk_id": "71115043cdf0_aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9iYmRhdGEvZG9jdW1lbnRfOS50eHQ1_pages_0", "chunk": "Cameras Surface Pro 4 has two cameras for taking photos and recording video: an 8-megapixel rear-facing camera with autofocus and a 5-megapixel; high-resolution; front-facing camera.", "@search.score": 0.44125757, "@search.reranker_score": null, "@search.highlights": null, "@search.captions": null}, {"title": "document_20.txt", "parent_id": "aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9iYmRhdGEvZG9jdW1lbnRfMjAudHh00", "chunk_id": "71115043cdf0_aHR0cHM6Ly9maXZvZGFjeHN0b3JlLmJsb2IuY29yZS53aW5kb3dzLm5ldC9iYmRhdGEvZG9jdW1lbnRfMjAudHh00_pages_0", "chunk": "Cameras Surface Pro 4 has two cameras for taking photos and recording video: an 8-megapixel rear-facing camera with autofocus and a 5-megapixel; high-resolution; front-facing camera. Both cameras record video in 1080p; with a 16:9 aspect ratio.", "@search.score": 0.35288104, "@search.reranker_score": null, "@search.highlights": null, "@search.captions": null}]
# **********************************************************************
#
# --------------------------------------------------------------------------------
# COGSearch (to User):
#
# Here is some information about the Surface Pro:
#
# 1. **Cameras**:
#    - The Surface Pro 4 has two cameras for taking photos and recording video:
#      - An 8-megapixel rear-facing camera with autofocus.
#      - A 5-megapixel high-resolution front-facing camera.
#    - Both cameras record video in 1080p with a 16:9 aspect ratio.
#
# If you need more details or have any other questions, feel free to ask! TERMINATE
#
# --------------------------------------------------------------------------------
